# %%
import requests

# %%
if 'host' not in globals():
  host = input("Enter your Gateway host url (http://localhost:8000/gemini): ") or "http://localhost:8000/gemini"

# %%
headers = {
    "Content-type": "application/json"
}

# %%
payload = {
    "messages": [
        {
            "role": "user",
            "content": [
                {
                    "type": "image_url",
                    "image_url": {
                        "url": "data:image/png;base64,..."
                    }
                },
                {
                    "type": "text",
                    "text": "What's in this image?"
                }
            ]
        }
    ]
}

# %%
response = requests.post(url, json=payload, headers=headers)

# %%
print(response.json())
# Out:
# {'object': 'chat.completion', 'choices': [{'message': {'content': "This image captures a celebratory moment for the Indian cricket team, likely after winning a major tournament, possibly the 2011 Cricket World Cup.  Sachin Tendulkar, a legendary Indian cricketer, is being hoisted onto the shoulders of his teammates. He holds an Indian flag aloft, and another large Indian flag is partially visible to his left.  The players are wearing the Indian cricket team's blue jerseys. The background is a blurred crowd, suggesting a stadium filled with spectators. The expressions of joy and triumph on the players' faces are evident.  The focus is on Tendulkar and the celebratory atmosphere surrounding him.\n", 'role': 'assistant'}, 'index': 0, 'finish_reason': 'stop'}], 'model': 'gemini-1.5-pro', 'usage': {'prompt_tokens': 265, 'completion_tokens': 129, 'total_tokens': 394}}
